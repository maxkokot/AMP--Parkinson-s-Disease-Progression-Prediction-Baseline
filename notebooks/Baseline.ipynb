# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import re

from gensim.models import word2vec
from sklearn.base import TransformerMixin
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.tree import ExtraTreeRegressor
from sklearn.metrics import r2_score, mean_absolute_error, \
    mean_squared_error
from sklearn.pipeline import Pipeline

from tsfresh.feature_extraction import extract_features

from xgboost import XGBRegressor
import optuna

# %%
MODELS = {'ExtraTreeRegressor': ExtraTreeRegressor,
          'Ridge': Ridge
          }

COL_TO_DEL = ['patient_id', 'patient_id_sum_values', 'patient_id_mean',
              'patient_id_maximum', 'patient_id_minimum',
              'patient_id_standard_deviation', 'patient_id_absolute_maximum',
              'visit_month_sum_values', 'visit_month_mean',
              'visit_month_maximum', 'visit_month_minimum',
              'visit_month_standard_deviation', 'visit_month_absolute_maximum']

TARGETS = ['updrs_1', 'updrs_2', 'updrs_3', 'updrs_4']

# %%
SETTINGS_LEVEL_1 = {'sum_values': None,
                    'mean': None,
                    'maximum': None,
                    'minimum': None,
                    'standard_deviation': None,
                    'absolute_maximum':  None,
                    'autocorrelation': [{'lag': 0}, {'lag': 1},
                                        {'lag': 2}, {'lag': 3},
                                        {'lag': 4}, {'lag': 5},
                                        {'lag': 6}],
                    'agg_autocorrelation': [{'f_agg': 'mean', 'maxlag': 40},
                                            {'f_agg': 'median', 'maxlag': 40},
                                            {'f_agg': 'var', 'maxlag': 40}]
                    }

SETTINGS_LEVEL_2 = {'sum_values': {'mean': None},
                    'mean': {'mean': None},
                    'length': {'mean': None,
                               'maximum': None,
                               'minimum': None},
                    'maximum': {'maximum': None,
                                'mean': None},
                    'minimum': {'minimum': None,
                                'mean': None},
                    'standard_deviation': {'mean': None},
                    'autocorrelation': {'mean': None}}

SETTINGS_LEVEL_3 = {'sum_values': None,
                    'mean': None,
                    'maximum': None,
                    'minimum': None,
                    'standard_deviation': None,
                    'absolute_maximum':  None}

# %%
def _split_all_data(peps, prots, clinical, train_patients, val_patients):
    train_peps = peps[peps.patient_id.isin(train_patients)] \
        .reset_index(drop=True)
    val_peps = peps[peps.patient_id.isin(val_patients)] \
        .reset_index(drop=True)

    train_prots = prots[prots.patient_id.isin(train_patients)] \
        .reset_index(drop=True)
    val_prots = prots[prots.patient_id.isin(val_patients)] \
        .reset_index(drop=True)

    train_clinical = clinical[clinical.patient_id.isin(train_patients)] \
        .reset_index(drop=True)
    val_clinical = clinical[clinical.patient_id.isin(val_patients)] \
        .reset_index(drop=True)
    return train_peps, val_peps, train_prots, val_prots, \
        train_clinical, val_clinical


def split_train_val_data(peps, prots, clinical, test_size, random_state):
    train_patients, val_patients = train_test_split(peps.patient_id.unique(),
                                                    test_size=test_size,
                                                    random_state=random_state)

    train_peps, val_peps, train_prots, val_prots, \
        train_clinical, val_clinical = _split_all_data(peps, prots,
                                                       clinical,
                                                       train_patients,
                                                       val_patients)

    return train_peps, val_peps, train_prots, val_prots, \
        train_clinical, val_clinical


def split_cv_data(peps, prots, clinical, train_idxs, val_idxs):

    train_peps, val_peps, train_prots, val_prots, \
        train_clinical, val_clinical = _split_all_data(peps, prots,
                                                       clinical,
                                                       train_idxs,
                                                       val_idxs)

    return train_peps, val_peps, train_prots, val_prots, \
        train_clinical, val_clinical

# %%
def create_config_pep(columns):

    config_pep = {col: {} for col in columns}
    config_pep[columns[0]].update({'length': None})

    for col in columns:
        config_pep[col].update(SETTINGS_LEVEL_1)

    return config_pep


def create_config_pep_prot(columns):

    config_pep_prot = {col: {} for col in columns}
    config_pep_prot[columns[0]].update({'length': None})

    for col in columns:
        for key in SETTINGS_LEVEL_2:
            if key in col:
                config_pep_prot[col] \
                    .update(SETTINGS_LEVEL_2[key])

    return config_pep_prot


def create_config_prot(columns):

    config_prot = {col: {} for col in columns}
    config_prot[columns[0]].update({'length': None})

    for col in columns:
        stop_indicator = False
        for key in SETTINGS_LEVEL_2:
            # stats for aggregative features
            if key in col:
                config_prot[col].update(SETTINGS_LEVEL_2[key])
                stop_indicator = True
        # stats for non aggregative features
        if not stop_indicator:
            config_prot[col].update(SETTINGS_LEVEL_3)

    return config_prot

# %%
def smape_func(y, y_pred, **kwargs):
    return 100/len(y) * np.sum(2 * np.abs(y_pred - y) /
                               (np.abs(y) + np.abs(y_pred)))

# %%
class W2vPepWrapper(TransformerMixin):
    """A class for applying word2vec for 
    encoding each character of peptides
    """
    def __init__(self, vector_size=30, window=5):
        self.vector_size = vector_size
        self.window = window
        self.cols = ['vector_pep_value_{}'.format(i)
                     for i in range(vector_size)]

    def _split_sequence(self, sequence):

        # We will separate single letters and UniMod strings
        # For example we want to split string 'ABCD(Unimod_4)EF like that:
        # A, B, C, D, Unimod, 4, E, F
        list_letters = sequence.split(r'(UniMod_')
        list_unimods = re.findall(r'\(UniMod_', sequence)

        list_letters = [letters.replace(')', '') for letters in list_letters]
        list_letters = [list(letters) for letters in list_letters]

        list_unimods = [unimod.replace(r'(', '') for unimod in list_unimods]
        list_unimods = [unimod.replace('_', '') for unimod in list_unimods]

        splitted_sequence = list_letters[0]

        if len(list_letters) > 1:

            for num in range(len(list_letters) - 1):
                splitted_sequence.append(list_unimods[num])
                splitted_sequence += list_letters[num + 1]

        elif len(list_unimods):
            splitted_sequence += list_unimods[0]

        return splitted_sequence

    def _create_vectors_df(self, splitted_sequence):
        vector_values = [self.w2v_model.wv.get_vector(symb)
                         for symb in splitted_sequence]
        vector_values = np.array(vector_values)
        vectors_df = pd.DataFrame(vector_values,
                                  columns=self.cols)
        vectors_df.index.name = 'Position'
        return vectors_df

    def _transform_peptides_to_vecs(self, peps):
        splitted_peps = self._split_sequence(peps.values[0])
        vec_df = self._create_vectors_df(splitted_peps)
        return vec_df

    def fit(self, X, y):
        peps, _, _ = X
        unique_peps = peps.Peptide.unique().astype('str')
        splitted_peps = [self._split_sequence(peptide_name)
                         for peptide_name in unique_peps]
        self.w2v_model = word2vec.Word2Vec(splitted_peps,
                                           vector_size=self.vector_size,
                                           window=self.window,
                                           workers=4)
        return self

    def transform(self, X):

        peps, prots, order = X
        peps_vectorized = peps.groupby('Peptide').Peptide \
            .apply(lambda x: self._transform_peptides_to_vecs(x))
        peps_vectorized = peps_vectorized.reset_index()
        return (peps, prots, order, peps_vectorized)


class W2vProtWrapper(TransformerMixin):
    """A class for applying word2vec for 
    encoding the names of proteins
    """
    def __init__(self, vector_size=30, window=100):
        self.vector_size = vector_size
        self.window = window
        self.cols = ['vector_prot_value_{}'.format(i)
                     for i in range(vector_size)]

    def _create_vectors_df(self, protein):
        if protein in self.w2v_model.wv:
            vector_values = self.w2v_model.wv.get_vector(protein)
        else:
            vector_values = self.w2v_model.wv.get_mean_vector(protein)
        vector_values = np.array(vector_values).reshape(1, -1)
        vectors_df = pd.DataFrame(vector_values, columns=self.cols)
        return vectors_df

    def _transform_protein_to_vecs(self, protein):

        vec_df = self._create_vectors_df(protein.values[0])
        return vec_df

    def fit(self, X, y):
        _, _, _, agg_prots = X
        prot_combinations = agg_prots.groupby('visit_id')['UniProt'] \
            .apply(lambda x: x.values).values
        prot_combinations = [list(prot_combination)
                             for prot_combination in prot_combinations]
        self.w2v_model = word2vec.Word2Vec(prot_combinations,
                                           vector_size=self.vector_size,
                                           window=self.window,
                                           workers=4)
        return self

    def transform(self, X):
        peps, prots, order, agg_prots = X
        agg_prots_vectorized = agg_prots.copy()
        prot_vectors = agg_prots_vectorized.groupby(['visit_id', 'UniProt']) \
            .UniProt.apply(lambda x: self._transform_protein_to_vecs(x))
        prot_vectors = prot_vectors.reset_index()
        agg_prots_vectorized = agg_prots_vectorized \
            .merge(prot_vectors, on=['visit_id', 'UniProt'])
        agg_prots_vectorized = agg_prots_vectorized.drop('UniProt', axis=1)
        return (peps, prots, order, agg_prots_vectorized)


class TSHandler(TransformerMixin):
    """A class for transforming set of vectors 
    into 1D vector
    """
    def __init__(self, chosen_idx, column_id, column_sort=None,
                 default_fc_parameters=None, config_function=None):
        self.chosen_idx = chosen_idx
        self.column_id = column_id
        self.column_sort = column_sort
        self.default_fc_parameters = default_fc_parameters
        self.config_function = config_function

    def fit(self, X, y):
        if self.config_function:
            self.default_fc_parameters = \
                self.config_function(X[self.chosen_idx].columns)

        return self

    def transform(self, X):
        agg_data = extract_features(X[self.chosen_idx],
                                    column_id=self.column_id,
                                    column_sort=self.column_sort,
                                    kind_to_fc_parameters=self
                                    .default_fc_parameters)
        agg_data.index.name = self.column_id
        agg_data = agg_data.reset_index()

        # replacing '__' with '_' to avoid problems further
        agg_data.columns = [col.replace('__', '_')
                            for col in agg_data.columns]
        final_list = list(X)
        final_list[self.chosen_idx] = agg_data
        final_tuple = tuple(final_list)
        return final_tuple


class PepInProtHandler(TransformerMixin):
    """A class for transforming set of vectors 
    (which correspond to set of peptides 
    for a certain protein belonging to 
    certain visit) into 1D vector
    """
    def __init__(self, default_fc_parameters={'mean': None},
                 config_function=None):
        self.default_fc_parameters = default_fc_parameters
        self.config_function = config_function

        # We don't want to compute stats for following features
        # since they remain constant for visit-prot combinations
        self.out_of_agg_cols = ['visit_id', 'visit_month',
                                'patient_id', 'UniProt',
                                'NPX', 'Peptide',
                                'PeptideAbundance']

    def _get_pep_prot_combos(self, prot_data, pep_data):
        pep_prot = prot_data \
            .merge(pep_data, on=['visit_id', 'UniProt',
                                 'visit_month', 'patient_id'])[['visit_id',
                                                                'visit_month',
                                                                'patient_id',
                                                                'UniProt',
                                                                'NPX',
                                                                'Peptide']]

        pep_prot_combos = pep_prot \
            .groupby(['visit_id', 'UniProt'])[['UniProt', 'Peptide']] \
            .apply(lambda x: ' ' + '.'.join(x['Peptide']))
        pep_prot_combos = pep_prot_combos.reset_index()
        pep_prot_combos.columns = ['visit_id', 'UniProt', 'pep_prot_combo']
        return pep_prot_combos

    def _remove_duplicate_from_prot_data(self, prot_data, pep_prot_combos):
        pep_prot_combos_rem_dup = pep_prot_combos \
            .drop_duplicates(subset='pep_prot_combo')
        prot_data_rem_dup = prot_data.merge(pep_prot_combos_rem_dup,
                                            on=['visit_id', 'UniProt'])
        return prot_data_rem_dup

    def fit(self, X, y):
        if self.config_function:
            self.default_fc_parameters = self.config_function(X[-1].columns)

        return self

    def transform(self, X):

        peps, prots, order, agg_peps = X

        # Here we remove duplicated combinations of prots and peps
        # for decreasing computational time
        pep_prot_combos = self._get_pep_prot_combos(prots, peps)
        prots_rem_dup = self._remove_duplicate_from_prot_data(prots,
                                                              pep_prot_combos)

        pep_prot_rem_dup = prots_rem_dup \
            .merge(peps, on=['visit_id', 'UniProt',
                             'visit_month', 'patient_id'])
        pep_prot_rem_dup = pep_prot_rem_dup \
            .merge(agg_peps, on=['Peptide']) \
            .drop(self.out_of_agg_cols, axis=1)

        # feature extraction for peptides sets
        agg_agg_peps = extract_features(pep_prot_rem_dup,
                                        column_id='pep_prot_combo',
                                        kind_to_fc_parameters=self
                                        .default_fc_parameters)
        agg_agg_peps.index.name = 'pep_prot_combo'
        agg_agg_peps = agg_agg_peps.reset_index()

        # replacing '__' with '_' to avoid problems further
        agg_agg_peps.columns = [col.replace('__', '_')
                                for col in agg_agg_peps.columns]

        # feature extraction for PeptideAbundance
        agg_abundance = peps.groupby(['visit_id', 'UniProt']) \
            .apply(lambda x: x.PeptideAbundance.mean())
        agg_abundance = agg_abundance.reset_index()
        agg_abundance.columns = ['visit_id', 'UniProt', 'PeptideAbundance']

        # merge everything
        agg_pep_prots = prots \
            .merge(pep_prot_combos, on=['visit_id', 'UniProt']) \
            .merge(agg_agg_peps, on='pep_prot_combo')
        agg_pep_prots = agg_pep_prots.merge(agg_abundance,
                                            on=['visit_id', 'UniProt'])
        agg_pep_prots = agg_pep_prots.drop('pep_prot_combo', axis=1)
        return (peps, prots, order, agg_pep_prots)


class OrderMaintainer(TransformerMixin):
    """A class for maintaining 
    initial order of visits
    """
    def __init__(self):
        pass

    def fit(self, X, y):
        return self

    def transform(self, X):
        peps, prots, order, agg_df = X
        agg_df_ordered = order.merge(agg_df,
                                     on=list(order.columns))
        return (peps, prots, order, agg_df_ordered)


class PatDateExtractor(TransformerMixin):
    """A class for extracting patient_id 
    and visit_month from visit_id
    """
    def __init__(self):
        pass

    def fit(self, X, y):
        return self

    def transform(self, X):
        peps, prots, order, agg_df = X
        agg_df_extracted = agg_df.copy()
        agg_df_extracted['patient_id'] = agg_df_extracted['visit_id'] \
            .apply(lambda x: x.split('_')[0]).astype('int')
        agg_df_extracted['visit_month'] = agg_df_extracted['visit_id'] \
            .apply(lambda x: x.split('_')[1]).astype('int')
        return (peps, prots, order, agg_df_extracted)


class ColumnDropper(TransformerMixin):
    """A class for dropping useless 
    or leak features
    """
    def __init__(self, cols):
        self.cols = cols

    def fit(self, X, y):
        return self

    def transform(self, X):
        return X.drop(self.cols, axis=1)


class DFSelector(TransformerMixin):
    """A class for selecting a certain 
    dataframe from a tuple of 
    several dataframes
    """
    def __init__(self, chosen_idx):
        self.chosen_idx = chosen_idx

    def fit(self, X, y):
        return self

    def transform(self, X):
        return X[self.chosen_idx]


class StandardScalerWrapper(StandardScaler):
    """A wrapper for StandardScaler 
    returning pd.DataFrame
    """
    def __init__(self, *, copy=True,
                 with_mean=True, with_std=True):
        super().__init__(copy=copy, with_mean=with_mean,
                         with_std=with_std)

    def transform(self, X):
        X_scaled = X.copy()
        X_scaled[X_scaled.columns] = super().transform(X)
        X_scaled['visit_id'] = X.visit_id
        return X_scaled


class FeatureSelectorWrapper(TransformerMixin):
    """A convenient wrapper for SelectFromModel 
    """
    def __init__(self, model, target_name,
                 params={}, max_rate_feats=.5):
        self.params = params
        self.model = model
        self.target_name = target_name
        self.max_rate_feats = max_rate_feats

    def _compute_max_features(self, X):
        max_features = int(np.round(X.shape[1] * self.max_rate_feats))

        if max_features == 0:
            max_features = 1

        return max_features

    def fit(self, X, y):
        Xy = X.merge(y[['visit_id', self.target_name]], on='visit_id')
        Xy = Xy.dropna(subset=self.target_name)
        X_ordered = Xy.drop([self.target_name], axis=1)
        y_ordered = Xy[self.target_name]
        max_features = self._compute_max_features(X_ordered)
        self.selector = SelectFromModel(self.model(**self.params),
                                        threshold=-np.inf,
                                        max_features=max_features)
        self.selector.fit(X_ordered, y_ordered)
        return self

    def transform(self, X):
        arr = self.selector.transform(X).astype('float')
        cols = self.selector.get_feature_names_out()
        df = pd.DataFrame(arr, columns=cols)
        df['visit_id'] = X['visit_id']
        return df
    
class ModelWrapper(TransformerMixin):
    """A convenient wrapper for final machine learning model 
    which drops instances where target is unknown 
    """
    def __init__(self, model, target_name, params={}):
        self.model = model(**params)
        self.target_name = target_name

    def fit(self, X, y):
        Xy = X.merge(y[['visit_id', self.target_name]], on='visit_id')
        Xy = Xy.dropna(subset=self.target_name)
        X_ordered = Xy.drop(['visit_id', self.target_name], axis=1)
        y_ordered = Xy[self.target_name]
        self.model.fit(X_ordered, y_ordered)
        return self

    def predict(self, X):
        return self.model.predict(X.drop('visit_id', axis=1))

# %%
def make_pipeline(pep_vector_size, pep_window_size,
                  prot_vector_size, prot_window_size,
                  model_for_fs, rate_for_fs, 
                  max_depth, learning_rate, 
                  n_estimators, min_child_weight,
                  gamma, current_target):
    
    param_xgb = {
        'max_depth': max_depth,
        'learning_rate': learning_rate,
        'n_estimators': n_estimators,
        'min_child_weight': min_child_weight,
        'gamma': gamma}

    pipeline = Pipeline([('w2pepvw', W2vPepWrapper(pep_vector_size,
                                                   pep_window_size)),
                         ('tsh1', TSHandler
                          (3, 'Peptide', 'Position',
                           config_function=create_config_pep)),
                         ('ph', PepInProtHandler
                          (config_function=create_config_pep_prot)),
                         ('om1', OrderMaintainer()),
                         ('w2protvw', W2vProtWrapper(prot_vector_size,
                                                     prot_window_size)),
                         ('tsh2', TSHandler
                          (3, 'visit_id', None,
                           config_function=create_config_prot)),
                         ('pde', PatDateExtractor()),
                         ('om2', OrderMaintainer()),
                         ('dfs', DFSelector(-1)),
                         ('cd', ColumnDropper(COL_TO_DEL)),
                         ('sc', StandardScalerWrapper()),
                         ('fsel', FeatureSelectorWrapper
                          (MODELS[model_for_fs],
                           current_target,
                           max_rate_feats=rate_for_fs)),
                         ('model', ModelWrapper(XGBRegressor,
                                                current_target,
                                                params=param_xgb))
                         ])

    return pipeline


def objective(trial):

    global current_target, train_peptides, train_proteins, train_clinical

    pep_vector_size = trial.suggest_int("pep_vector_size", 5, 50)
    pep_window_size = trial.suggest_int("pep_window_size", 3, 20)

    prot_vector_size = trial.suggest_int("prot_vector_size", 5, 50)
    prot_window_size = trial.suggest_int("prot_window_size", 3, 10)

    model_for_fs = trial.suggest_categorical('model_for_fs',
                                             ['ExtraTreeRegressor', 'Ridge'])
    rate_for_fs = trial.suggest_float('rate_for_fs', 0.01, 0.99)

    max_depth = trial.suggest_int('max_depth', 1, 10)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 1.0)
    n_estimators = trial.suggest_int('n_estimators', 50, 1000)
    min_child_weight = trial.suggest_int('min_child_weight', 1, 10)
    gamma = trial.suggest_float('gamma', 0.01, 1.0)

    pipe = make_pipeline(pep_vector_size, pep_window_size,
                         prot_vector_size, prot_window_size,
                         model_for_fs, rate_for_fs, 
                         max_depth, learning_rate, 
                         n_estimators, min_child_weight,
                         gamma, current_target)

    cv = KFold(3, shuffle=True, random_state=22)
    patient_ids = train_peptides.patient_id.unique()
    smape_scores = []

    for train_idxs, val_idxs in cv.split(patient_ids):

        smape_score = _fit_and_score_cv(pipe, train_peptides,
                                        train_proteins,
                                        train_clinical,
                                        current_target,
                                        train_idxs, val_idxs)
        smape_scores.append(smape_score)

    mean_smape_score = np.mean(smape_scores)
    return mean_smape_score


def _fit_and_score_cv(pipe, peps, prots,
                      clinical, current_target,
                      train_idxs, val_idxs):
    patient_ids = peps.patient_id.unique()
    train_ids = patient_ids[train_idxs]
    val_ids = patient_ids[val_idxs]

    train_peps, val_peps, \
        train_prots, val_prots, \
        train_clinical, val_clinical = \
        split_cv_data(peps, prots,
                      clinical, train_ids, val_ids)

    train_order = train_peps[[
        'patient_id', 'visit_month']].drop_duplicates()
    val_order = val_peps[[
        'patient_id', 'visit_month']].drop_duplicates()

    pipe.fit((train_peps,
              train_prots,
              train_order), train_clinical)
    preds = pipe.predict((val_peps,
                          val_prots,
                          val_order))

    preds_val_df = val_order.copy()
    preds_val_df['pred'] = preds

    true_pred = preds_val_df \
        .merge(val_clinical, on=['patient_id',
                                 'visit_month'])
    true_pred = true_pred.dropna(subset=current_target)

    smape_score = smape_func(true_pred[current_target].values,
                             true_pred['pred'].values)
    return smape_score

# %% [markdown]
# ## Brief description of solution

# %% [markdown]
# As we have seen during EDA, each patient has several visits. Each visit has a certain set of proteins, and then each protein related to this visit has its own set of peptides, which are represented as sequences of characters. In order to preserve all the information, we've done folowing steps:
#
# 1. Applying word2vec for encoding each character of peptides
# 2. Applying tsfresh for transforming sequence of obtained vectors into 1D vector
# 3. Applying tsfresh for transforming set of vectors (which correspond to set of peptides for a certain protein belonging to certain visit) into 1D vector
# 4. Applying word2vec for encoding the names of proteins
# 5. Applying tsfresh for transforming visit data (encoded protein names belonging to certain visit + data obtained into step 3) into 1D vector
# 6. Applying xgboost regressor
#
# For tuning hyperparameters of xgboost and each step of preprocessing we've used optuna.

# %% [markdown]
# ## Reading input data

# %%
peptides = pd.read_csv('../data/raw/train_peptides.csv')
proteins = pd.read_csv('../data/raw/train_proteins.csv')
clinical = pd.read_csv('../data/raw/train_clinical_data.csv')

# %% [markdown]
# We split all datasets by patients

# %%
train_peptides, test_peptides, \
    train_proteins, test_proteins, \
    train_clinical, test_clinical = split_train_val_data(peptides,
                                                         proteins,
                                                         clinical,
                                                         test_size=.2,
                                                         random_state=20)

print(train_clinical.shape, test_clinical.shape)
# Out:
# (2110, 8) (505, 8)

# %%
train_order = train_proteins[[
    'patient_id', 'visit_month']].drop_duplicates()
test_order = test_proteins[[
    'patient_id', 'visit_month']].drop_duplicates()

# %% [markdown]
# ## updrs_1

# %%
current_target = 'updrs_1'
study_1 = optuna.create_study()
study_1.optimize(objective, n_trials=10)
# Out:
# [I 2023-04-07 22:00:44,852] A new study created in memory with name: no-name-f1f11a3f-3893-4cea-90a1-e8141942afd0
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.70it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:47<00:00,  8.35s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:42<00:00,  2.11s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.62it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:56<00:00,  5.82s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.09s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.72it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:53<00:00,  8.69s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:41<00:00,  2.08s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.69it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:50<00:00,  5.52s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:22<00:00,  1.11s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.69it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:47<00:00,  8.39s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:41<00:00,  2.05s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.74it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:54<00:00,  5.71s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:22<00:00,  1.12s/it]
# [I 2023-04-07 22:23:11,767] Trial 0 finished with value: 70.52183713709434 and parameters: {'pep_vector_size': 40, 'pep_window_size': 3, 'prot_vector_size': 43, 'prot_window_size': 9, 'model_for_fs': 'ExtraTreeRegressor', 'threshold_for_ts': 0.6022248267569663, 'max_depth': 7, 'learning_rate': 0.17014878762466404, 'n_estimators': 683, 'min_child_weight': 3, 'gamma': 0.25343698536527814}. Best is trial 0 with value: 70.52183713709434.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.23it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:43<00:00,  5.17s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:26<00:00,  1.34s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.32it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:12<00:00,  3.61s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:14<00:00,  1.40it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.30it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:45<00:00,  5.29s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:26<00:00,  1.33s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.30it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:09<00:00,  3.47s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:14<00:00,  1.38it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.26it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:43<00:00,  5.16s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:26<00:00,  1.31s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.30it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:12<00:00,  3.61s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:14<00:00,  1.34it/s]
# [I 2023-04-07 22:38:07,300] Trial 1 finished with value: 74.90081655007675 and parameters: {'pep_vector_size': 26, 'pep_window_size': 18, 'prot_vector_size': 8, 'prot_window_size': 7, 'model_for_fs': 'ExtraTreeRegressor', 'threshold_for_ts': 0.2052980253227712, 'max_depth': 5, 'learning_rate': 0.4035990799371091, 'n_estimators': 212, 'min_child_weight': 10, 'gamma': 0.019591183379363317}. Best is trial 0 with value: 70.52183713709434.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  2.95it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:07<00:00,  3.37s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:19<00:00,  1.03it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  2.96it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:47<00:00,  2.35s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.83it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  2.89it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:08<00:00,  3.43s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:18<00:00,  1.06it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  2.95it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:46<00:00,  2.32s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.76it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  2.91it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:08<00:00,  3.40s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:19<00:00,  1.01it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.84it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:48<00:00,  2.43s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.75it/s]
# [I 2023-04-07 22:49:11,774] Trial 2 finished with value: 69.83547472232921 and parameters: {'pep_vector_size': 17, 'pep_window_size': 12, 'prot_vector_size': 23, 'prot_window_size': 9, 'model_for_fs': 'ExtraTreeRegressor', 'threshold_for_ts': 0.5118759419179546, 'max_depth': 6, 'learning_rate': 0.13158943682751476, 'n_estimators': 115, 'min_child_weight': 7, 'gamma': 0.3083995300599445}. Best is trial 2 with value: 69.83547472232921.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.24it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:55<00:00,  2.80s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:16<00:00,  1.22it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.21it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:40<00:00,  2.01s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.22it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.26it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:56<00:00,  2.83s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:15<00:00,  1.28it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.23it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:38<00:00,  1.92s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.10it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.14it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:56<00:00,  2.83s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:15<00:00,  1.25it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.14it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:39<00:00,  1.97s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.06it/s]
# [I 2023-04-07 22:58:59,896] Trial 3 finished with value: 82.10994565047054 and parameters: {'pep_vector_size': 14, 'pep_window_size': 10, 'prot_vector_size': 5, 'prot_window_size': 4, 'model_for_fs': 'ExtraTreeRegressor', 'threshold_for_ts': 0.8039194981237694, 'max_depth': 10, 'learning_rate': 0.7325150779348673, 'n_estimators': 379, 'min_child_weight': 7, 'gamma': 0.9163387472423955}. Best is trial 2 with value: 69.83547472232921.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.58it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:11<00:00,  9.58s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:47<00:00,  2.37s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.91831e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.51it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:13<00:00,  6.68s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:24<00:00,  1.21s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.57it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:14<00:00,  9.75s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:47<00:00,  2.36s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.55087e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.58it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:07<00:00,  6.36s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:24<00:00,  1.21s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.59it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:10<00:00,  9.50s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:45<00:00,  2.28s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.55863e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.58it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:12<00:00,  6.61s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:25<00:00,  1.26s/it]
# [I 2023-04-07 23:23:57,987] Trial 4 finished with value: 87.21809185738056 and parameters: {'pep_vector_size': 45, 'pep_window_size': 5, 'prot_vector_size': 49, 'prot_window_size': 10, 'model_for_fs': 'Ridge', 'threshold_for_ts': 0.42084583117253405, 'max_depth': 9, 'learning_rate': 0.893224037025346, 'n_estimators': 511, 'min_child_weight': 2, 'gamma': 0.9528770552055313}. Best is trial 2 with value: 69.83547472232921.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.68it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:19<00:00,  3.96s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:22<00:00,  1.12s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.35645e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.68it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:55<00:00,  2.76s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.63it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.69it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:21<00:00,  4.06s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:22<00:00,  1.10s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.01336e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.73it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:53<00:00,  2.65s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.60it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.68it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:19<00:00,  3.96s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:22<00:00,  1.11s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.83992e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.68it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:55<00:00,  2.77s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.59it/s]
# [I 2023-04-07 23:36:20,818] Trial 5 finished with value: 75.53769274325204 and parameters: {'pep_vector_size': 20, 'pep_window_size': 18, 'prot_vector_size': 23, 'prot_window_size': 5, 'model_for_fs': 'Ridge', 'threshold_for_ts': 0.6808554627135651, 'max_depth': 5, 'learning_rate': 0.5674891041221098, 'n_estimators': 188, 'min_child_weight': 7, 'gamma': 0.5495088445326896}. Best is trial 2 with value: 69.83547472232921.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:04<00:00,  4.27it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:29<00:00,  1.46s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.76it/s]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.54771e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Feature Extraction: 100%|██████████████████████| 20/20 [00:04<00:00,  4.17it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.06s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  2.86it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:04<00:00,  4.18it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:29<00:00,  1.47s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.82it/s]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.21616e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Feature Extraction: 100%|██████████████████████| 20/20 [00:04<00:00,  4.16it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:20<00:00,  1.03s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  2.86it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:04<00:00,  4.11it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:30<00:00,  1.53s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.73it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:04<00:00,  4.15it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.07s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  2.87it/s]
# [I 2023-04-07 23:43:23,293] Trial 6 finished with value: 88.50109729861514 and parameters: {'pep_vector_size': 7, 'pep_window_size': 15, 'prot_vector_size': 38, 'prot_window_size': 4, 'model_for_fs': 'Ridge', 'threshold_for_ts': 0.5740349062622196, 'max_depth': 6, 'learning_rate': 0.8936595188100164, 'n_estimators': 780, 'min_child_weight': 2, 'gamma': 0.6200192510408932}. Best is trial 2 with value: 69.83547472232921.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.47it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:32<00:00,  4.64s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:25<00:00,  1.26s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=6.99736e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.41it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:04<00:00,  3.21s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.48it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.43it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:35<00:00,  4.76s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:24<00:00,  1.24s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=6.0547e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.50it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:01<00:00,  3.07s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.46it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.42it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:30<00:00,  4.55s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:24<00:00,  1.22s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.12603e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.04it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:08<00:00,  3.40s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.44it/s]
# [I 2023-04-07 23:57:14,718] Trial 7 finished with value: 86.59417808814959 and parameters: {'pep_vector_size': 23, 'pep_window_size': 17, 'prot_vector_size': 15, 'prot_window_size': 8, 'model_for_fs': 'Ridge', 'threshold_for_ts': 0.33001245764394616, 'max_depth': 1, 'learning_rate': 0.7122780668511944, 'n_estimators': 310, 'min_child_weight': 8, 'gamma': 0.3859204970681996}. Best is trial 2 with value: 69.83547472232921.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.47it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:24<00:00, 10.21s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:49<00:00,  2.45s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.92506e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.50it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:21<00:00,  7.09s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:25<00:00,  1.26s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.46it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:31<00:00, 10.56s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:48<00:00,  2.45s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.80858e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.49it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:16<00:00,  6.82s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:25<00:00,  1.28s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.48it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:37<00:00, 10.86s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:49<00:00,  2.49s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.49727e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:14<00:00,  1.40it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:27<00:00,  7.38s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:27<00:00,  1.38s/it]
# [I 2023-04-08 00:23:46,802] Trial 8 finished with value: 74.8453098279477 and parameters: {'pep_vector_size': 48, 'pep_window_size': 8, 'prot_vector_size': 29, 'prot_window_size': 7, 'model_for_fs': 'Ridge', 'threshold_for_ts': 0.5752687483015012, 'max_depth': 2, 'learning_rate': 0.3545106958947955, 'n_estimators': 230, 'min_child_weight': 8, 'gamma': 0.77414726222644}. Best is trial 2 with value: 69.83547472232921.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.86it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:15<00:00,  6.76s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:33<00:00,  1.67s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.98it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:31<00:00,  4.59s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:17<00:00,  1.14it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.95it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:18<00:00,  6.91s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:33<00:00,  1.65s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.97it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:27<00:00,  4.35s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:17<00:00,  1.13it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.98it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:12<00:00,  6.63s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:31<00:00,  1.60s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.03it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:33<00:00,  4.66s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:18<00:00,  1.08it/s]
# [I 2023-04-08 00:42:05,057] Trial 9 finished with value: 74.20789517489389 and parameters: {'pep_vector_size': 32, 'pep_window_size': 3, 'prot_vector_size': 17, 'prot_window_size': 10, 'model_for_fs': 'ExtraTreeRegressor', 'threshold_for_ts': 0.43994558664436345, 'max_depth': 5, 'learning_rate': 0.39096757260599224, 'n_estimators': 344, 'min_child_weight': 10, 'gamma': 0.3799634910850591}. Best is trial 2 with value: 69.83547472232921.

# %%
study_1.best_params
# Out:
# {'pep_vector_size': 17,
#  'pep_window_size': 12,
#  'prot_vector_size': 23,
#  'prot_window_size': 9,
#  'model_for_fs': 'ExtraTreeRegressor',
#  'rate_for_ts': 0.5118759419179546,
#  'max_depth': 6,
#  'learning_rate': 0.13158943682751476,
#  'n_estimators': 115,
#  'min_child_weight': 7,
#  'gamma': 0.3083995300599445}

# %%
pipe_1 = make_pipeline(current_target=current_target, **study_1.best_params)
pipe_1.fit((train_peptides, train_proteins, train_order), train_clinical)
# Out:
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.85it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:28<00:00,  4.43s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:28<00:00,  1.41s/it]

# %%
preds_updrs_1_test = pipe_1.predict((test_peptides, test_proteins, test_order))
# Out:
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  2.86it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:38<00:00,  1.94s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.13it/s]

# %%
preds_test_df = test_order.copy()
preds_test_df['pred'] = preds_updrs_1_test

# %%
true_pred = preds_test_df.merge(test_clinical, on = ['patient_id', 'visit_month'])
true_pred = true_pred.dropna(subset='updrs_1')

# %%
print(smape_func(true_pred.updrs_1.values, 
                 true_pred['pred'].values))
# Out:
# 79.79190020509107

# %% [markdown]
# ## updrs_2

# %%
current_target = 'updrs_2'
study_2 = optuna.create_study()
study_2.optimize(objective, n_trials=10)
# Out:
# [I 2023-04-08 00:57:52,761] A new study created in memory with name: no-name-0f44e85d-dcb0-423f-9e82-62306e4b0200
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.65it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:59<00:00,  8.95s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:43<00:00,  2.16s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.84858e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.65it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:02<00:00,  6.14s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:22<00:00,  1.11s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.67it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:02<00:00,  9.13s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:42<00:00,  2.15s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.2622e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.65it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:57<00:00,  5.86s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:22<00:00,  1.14s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.64it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:52<00:00,  8.62s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:41<00:00,  2.05s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.39923e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.65it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:59<00:00,  5.96s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:22<00:00,  1.14s/it]
# [I 2023-04-08 01:20:57,788] Trial 0 finished with value: 107.52490376382512 and parameters: {'pep_vector_size': 42, 'pep_window_size': 5, 'prot_vector_size': 23, 'prot_window_size': 3, 'model_for_fs': 'Ridge', 'rate_for_fs': 0.807095896289993, 'max_depth': 5, 'learning_rate': 0.5802771459241671, 'n_estimators': 450, 'min_child_weight': 5, 'gamma': 0.47813917470986445}. Best is trial 0 with value: 107.52490376382512.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  2.87it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:05<00:00,  3.30s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:20<00:00,  1.02s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.8987e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  2.97it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:46<00:00,  2.33s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.77it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  2.93it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:07<00:00,  3.39s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:20<00:00,  1.01s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.25812e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  2.92it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:44<00:00,  2.25s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.71it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  2.99it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:06<00:00,  3.30s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:20<00:00,  1.04s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.03197e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  2.96it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:48<00:00,  2.44s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.64it/s]
# [I 2023-04-08 01:32:00,679] Trial 1 finished with value: 104.9122780367379 and parameters: {'pep_vector_size': 17, 'pep_window_size': 19, 'prot_vector_size': 44, 'prot_window_size': 4, 'model_for_fs': 'Ridge', 'rate_for_fs': 0.2554937907605241, 'max_depth': 3, 'learning_rate': 0.16900234617568224, 'n_estimators': 692, 'min_child_weight': 2, 'gamma': 0.996424060555293}. Best is trial 1 with value: 104.9122780367379.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.48it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:23<00:00, 10.18s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:48<00:00,  2.43s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.52it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:21<00:00,  7.06s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:24<00:00,  1.23s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.50it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:26<00:00, 10.34s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:48<00:00,  2.41s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.46it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:14<00:00,  6.71s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:24<00:00,  1.23s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.54it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:17<00:00,  9.89s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:45<00:00,  2.29s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.56it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:15<00:00,  6.80s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:24<00:00,  1.24s/it]
# [I 2023-04-08 01:57:35,876] Trial 2 finished with value: 107.0712240636823 and parameters: {'pep_vector_size': 47, 'pep_window_size': 12, 'prot_vector_size': 22, 'prot_window_size': 6, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.538686484205448, 'max_depth': 3, 'learning_rate': 0.4421097417990337, 'n_estimators': 329, 'min_child_weight': 8, 'gamma': 0.6325100877555762}. Best is trial 1 with value: 104.9122780367379.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.85it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:31<00:00,  7.58s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:38<00:00,  1.95s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.85it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:44<00:00,  5.25s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:20<00:00,  1.04s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.82it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:40<00:00,  8.02s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:41<00:00,  2.05s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.79it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:43<00:00,  5.20s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.05s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.75it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:39<00:00,  7.97s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:39<00:00,  1.96s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.81it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:50<00:00,  5.53s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.10s/it]
# [I 2023-04-08 02:18:33,537] Trial 3 finished with value: 115.68998889885198 and parameters: {'pep_vector_size': 37, 'pep_window_size': 9, 'prot_vector_size': 41, 'prot_window_size': 9, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.3825044651863448, 'max_depth': 2, 'learning_rate': 0.729191609383936, 'n_estimators': 757, 'min_child_weight': 1, 'gamma': 0.013560025242294736}. Best is trial 1 with value: 104.9122780367379.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.37it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:38<00:00,  4.92s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:26<00:00,  1.35s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.14811e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.33it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:08<00:00,  3.43s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:14<00:00,  1.41it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.40it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:38<00:00,  4.91s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:25<00:00,  1.29s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.14245e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.37it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:04<00:00,  3.21s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:14<00:00,  1.42it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.37it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:35<00:00,  4.76s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:25<00:00,  1.29s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.03608e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.40it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:06<00:00,  3.33s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:14<00:00,  1.36it/s]
# [I 2023-04-08 02:32:55,928] Trial 4 finished with value: 109.44522319949651 and parameters: {'pep_vector_size': 24, 'pep_window_size': 19, 'prot_vector_size': 25, 'prot_window_size': 4, 'model_for_fs': 'Ridge', 'rate_for_fs': 0.9282467961354314, 'max_depth': 1, 'learning_rate': 0.5164801472719333, 'n_estimators': 771, 'min_child_weight': 8, 'gamma': 0.6545052953768334}. Best is trial 1 with value: 104.9122780367379.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.61it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:23<00:00,  4.20s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:24<00:00,  1.21s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.60it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:58<00:00,  2.91s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.49it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.53it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:23<00:00,  4.18s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:23<00:00,  1.19s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.64it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:54<00:00,  2.74s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.52it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.62it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:22<00:00,  4.11s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:23<00:00,  1.19s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.62it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:56<00:00,  2.84s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.48it/s]
# [I 2023-04-08 02:45:43,570] Trial 5 finished with value: 107.33078576551327 and parameters: {'pep_vector_size': 21, 'pep_window_size': 6, 'prot_vector_size': 49, 'prot_window_size': 4, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.8634083609955948, 'max_depth': 4, 'learning_rate': 0.3756579436761573, 'n_estimators': 83, 'min_child_weight': 3, 'gamma': 0.2722342405996997}. Best is trial 1 with value: 104.9122780367379.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.74it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:44<00:00,  8.24s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:40<00:00,  2.04s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.74it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:53<00:00,  5.67s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:20<00:00,  1.05s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.75it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:49<00:00,  8.45s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:40<00:00,  2.05s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.73it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:48<00:00,  5.43s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.09s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.74it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:43<00:00,  8.19s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:40<00:00,  2.04s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.74it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:52<00:00,  5.63s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.10s/it]
# [I 2023-04-08 03:07:25,040] Trial 6 finished with value: 100.33735059191487 and parameters: {'pep_vector_size': 40, 'pep_window_size': 8, 'prot_vector_size': 36, 'prot_window_size': 5, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.4135469687798218, 'max_depth': 8, 'learning_rate': 0.06184973515438345, 'n_estimators': 263, 'min_child_weight': 4, 'gamma': 0.32609672246286237}. Best is trial 6 with value: 100.33735059191487.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.56it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:12<00:00,  9.61s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:47<00:00,  2.35s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.59it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:13<00:00,  6.66s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:23<00:00,  1.18s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.57it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:20<00:00, 10.02s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:47<00:00,  2.36s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.56it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:10<00:00,  6.54s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:24<00:00,  1.25s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.54it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:17<00:00,  9.89s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:46<00:00,  2.32s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.54it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:14<00:00,  6.72s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:24<00:00,  1.25s/it]
# [I 2023-04-08 03:32:29,438] Trial 7 finished with value: 113.91458677445286 and parameters: {'pep_vector_size': 46, 'pep_window_size': 14, 'prot_vector_size': 41, 'prot_window_size': 4, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.5660516375609467, 'max_depth': 2, 'learning_rate': 0.8084970455183322, 'n_estimators': 552, 'min_child_weight': 10, 'gamma': 0.8898390420196384}. Best is trial 6 with value: 100.33735059191487.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.50it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:25<00:00, 10.28s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:47<00:00,  2.40s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=7.81827e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.49it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:23<00:00,  7.20s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:24<00:00,  1.23s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.51it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:30<00:00, 10.51s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:47<00:00,  2.38s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.03963e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.49it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:17<00:00,  6.89s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:25<00:00,  1.25s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.50it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:25<00:00, 10.27s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:46<00:00,  2.35s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.67511e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.48it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:23<00:00,  7.18s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:25<00:00,  1.27s/it]
# [I 2023-04-08 03:58:38,535] Trial 8 finished with value: 109.41133921121913 and parameters: {'pep_vector_size': 49, 'pep_window_size': 20, 'prot_vector_size': 12, 'prot_window_size': 7, 'model_for_fs': 'Ridge', 'rate_for_fs': 0.44550479507989055, 'max_depth': 7, 'learning_rate': 0.5140631524350685, 'n_estimators': 436, 'min_child_weight': 6, 'gamma': 0.5539979421803508}. Best is trial 6 with value: 100.33735059191487.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.62it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:03<00:00,  9.19s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:44<00:00,  2.22s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.61it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:07<00:00,  6.36s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:22<00:00,  1.13s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.60it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:13<00:00,  9.65s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:43<00:00,  2.19s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.57it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:00<00:00,  6.03s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:22<00:00,  1.15s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.58it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:02<00:00,  9.12s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:42<00:00,  2.14s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.62it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:07<00:00,  6.39s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:23<00:00,  1.17s/it]
# [I 2023-04-08 04:22:22,387] Trial 9 finished with value: 110.8880396809321 and parameters: {'pep_vector_size': 44, 'pep_window_size': 9, 'prot_vector_size': 23, 'prot_window_size': 5, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.5404434219722286, 'max_depth': 1, 'learning_rate': 0.6898890556277321, 'n_estimators': 505, 'min_child_weight': 4, 'gamma': 0.44008201472884767}. Best is trial 6 with value: 100.33735059191487.

# %%
study_2.best_params
# Out:
# {'pep_vector_size': 40,
#  'pep_window_size': 8,
#  'prot_vector_size': 36,
#  'prot_window_size': 5,
#  'model_for_fs': 'ExtraTreeRegressor',
#  'rate_for_fs': 0.4135469687798218,
#  'max_depth': 8,
#  'learning_rate': 0.06184973515438345,
#  'n_estimators': 263,
#  'min_child_weight': 4,
#  'gamma': 0.32609672246286237}

# %%
pipe_2 = make_pipeline(current_target=current_target, **study_2.best_params)
pipe_2.fit((train_peptides, train_proteins, train_order), train_clinical)
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:17<00:00,  1.13it/s]
# Feature Extraction: 100%|██████████| 20/20 [04:57<00:00, 14.85s/it]
# Feature Extraction: 100%|██████████| 20/20 [01:31<00:00,  4.58s/it]

# %%
preds_updrs_2_test = pipe_2.predict((test_peptides, test_proteins, test_order))
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:17<00:00,  1.17it/s]
# Feature Extraction: 100%|██████████| 20/20 [02:11<00:00,  6.60s/it]
# Feature Extraction: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it]
# /home/max/anaconda3/lib/python3.9/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
# /home/max/anaconda3/lib/python3.9/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)

# %%
preds_test_df = test_order.copy()
preds_test_df['pred'] = preds_updrs_2_test

# %%
true_pred = preds_test_df.merge(test_clinical, on = ['patient_id', 'visit_month'])
true_pred = true_pred.dropna(subset='updrs_2')

# %%
print(smape_func(true_pred.updrs_2.values, 
                 true_pred['pred'].values))
# Out:
# 104.39986880561862

# %% [markdown]
# ## updrs_3

# %%
current_target = 'updrs_3'
study_3 = optuna.create_study()
study_3.optimize(objective, n_trials=10)
# Out:
# [I 2023-04-08 04:22:22,397] A new study created in memory with name: no-name-099a833f-535a-4b62-9819-d3f817069d2c
# Feature Extraction: 100%|██████████████████████| 20/20 [00:05<00:00,  3.63it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:43<00:00,  2.17s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.49it/s]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.41173e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Feature Extraction: 100%|██████████████████████| 20/20 [00:05<00:00,  3.60it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:31<00:00,  1.56s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.53it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:05<00:00,  3.68it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:44<00:00,  2.22s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.50it/s]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.86734e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Feature Extraction: 100%|██████████████████████| 20/20 [00:05<00:00,  3.66it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:29<00:00,  1.48s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.43it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:05<00:00,  3.59it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:43<00:00,  2.17s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.52it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:05<00:00,  3.64it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:31<00:00,  1.57s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:08<00:00,  2.41it/s]
# [I 2023-04-08 04:30:40,764] Trial 0 finished with value: 114.60439299406926 and parameters: {'pep_vector_size': 11, 'pep_window_size': 16, 'prot_vector_size': 14, 'prot_window_size': 8, 'model_for_fs': 'Ridge', 'rate_for_fs': 0.27605985725823307, 'max_depth': 9, 'learning_rate': 0.9619795576132285, 'n_estimators': 405, 'min_child_weight': 6, 'gamma': 0.6950942054185735}. Best is trial 0 with value: 114.60439299406926.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.60it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:08<00:00,  9.42s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:46<00:00,  2.32s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.58it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:09<00:00,  6.49s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:23<00:00,  1.17s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.60it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:11<00:00,  9.58s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:45<00:00,  2.28s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.61it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:05<00:00,  6.26s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:24<00:00,  1.20s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.62it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:07<00:00,  9.40s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:45<00:00,  2.26s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.59it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:09<00:00,  6.47s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:24<00:00,  1.23s/it]
# [I 2023-04-08 04:54:53,541] Trial 1 finished with value: 100.4848357572472 and parameters: {'pep_vector_size': 45, 'pep_window_size': 12, 'prot_vector_size': 49, 'prot_window_size': 6, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.12650756594584733, 'max_depth': 6, 'learning_rate': 0.6602374498948507, 'n_estimators': 377, 'min_child_weight': 7, 'gamma': 0.9302004145723556}. Best is trial 1 with value: 100.4848357572472.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.66it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:17<00:00,  3.89s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.06s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.65it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:54<00:00,  2.71s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.70it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.71it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:19<00:00,  3.97s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:20<00:00,  1.05s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.66it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:52<00:00,  2.64s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.70it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.74it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:18<00:00,  3.90s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:20<00:00,  1.04s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.71it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:54<00:00,  2.71s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.62it/s]
# [I 2023-04-08 05:06:58,888] Trial 2 finished with value: 101.59255351002106 and parameters: {'pep_vector_size': 20, 'pep_window_size': 4, 'prot_vector_size': 6, 'prot_window_size': 3, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.2040499216374086, 'max_depth': 6, 'learning_rate': 0.5820514563213384, 'n_estimators': 637, 'min_child_weight': 4, 'gamma': 0.6103294506323692}. Best is trial 1 with value: 100.4848357572472.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.60it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:07<00:00,  9.39s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:45<00:00,  2.27s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=4.40067e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.61it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:10<00:00,  6.52s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:23<00:00,  1.17s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.60it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:11<00:00,  9.57s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:44<00:00,  2.24s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.57532e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.62it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:05<00:00,  6.26s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:23<00:00,  1.19s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.57it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:06<00:00,  9.34s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:44<00:00,  2.24s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.34485e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.55it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:10<00:00,  6.51s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:24<00:00,  1.21s/it]
# [I 2023-04-08 05:31:09,377] Trial 3 finished with value: 99.28795747868656 and parameters: {'pep_vector_size': 45, 'pep_window_size': 9, 'prot_vector_size': 37, 'prot_window_size': 4, 'model_for_fs': 'Ridge', 'rate_for_fs': 0.1367662510908947, 'max_depth': 2, 'learning_rate': 0.27533119767858366, 'n_estimators': 933, 'min_child_weight': 3, 'gamma': 0.27867934316679777}. Best is trial 3 with value: 99.28795747868656.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.49it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:27<00:00, 10.36s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:47<00:00,  2.39s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.49it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:22<00:00,  7.11s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:24<00:00,  1.23s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.48it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:31<00:00, 10.57s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:47<00:00,  2.38s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.49it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:16<00:00,  6.84s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:25<00:00,  1.25s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.47it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:26<00:00, 10.31s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:47<00:00,  2.36s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:13<00:00,  1.48it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:24<00:00,  7.21s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:25<00:00,  1.26s/it]
# [I 2023-04-08 05:57:20,498] Trial 4 finished with value: 92.31042418115045 and parameters: {'pep_vector_size': 49, 'pep_window_size': 13, 'prot_vector_size': 8, 'prot_window_size': 10, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.2918732060340875, 'max_depth': 7, 'learning_rate': 0.02591584266122024, 'n_estimators': 634, 'min_child_weight': 2, 'gamma': 0.5164584865786107}. Best is trial 4 with value: 92.31042418115045.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:05<00:00,  3.87it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:36<00:00,  1.81s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.72it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:05<00:00,  3.93it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:26<00:00,  1.31s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.81it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:04<00:00,  4.09it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:36<00:00,  1.85s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.82it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:04<00:00,  4.01it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:25<00:00,  1.25s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.74it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:05<00:00,  3.92it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:36<00:00,  1.80s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.76it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:04<00:00,  4.02it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:25<00:00,  1.29s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.73it/s]
# [I 2023-04-08 06:04:49,717] Trial 5 finished with value: 101.13212073887888 and parameters: {'pep_vector_size': 9, 'pep_window_size': 6, 'prot_vector_size': 9, 'prot_window_size': 4, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.42278365445880806, 'max_depth': 6, 'learning_rate': 0.46642126023909003, 'n_estimators': 822, 'min_child_weight': 2, 'gamma': 0.0516261464309239}. Best is trial 4 with value: 92.31042418115045.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.85it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:27<00:00,  7.36s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:36<00:00,  1.83s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.83it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:40<00:00,  5.05s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:19<00:00,  1.03it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.90it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:30<00:00,  7.52s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:36<00:00,  1.82s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=5.74117e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.88it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:35<00:00,  4.78s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:19<00:00,  1.02it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.89it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:27<00:00,  7.37s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:35<00:00,  1.80s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=3.41719e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.88it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:41<00:00,  5.05s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:20<00:00,  1.00s/it]
# [I 2023-04-08 06:24:28,092] Trial 6 finished with value: 98.92947189649509 and parameters: {'pep_vector_size': 36, 'pep_window_size': 13, 'prot_vector_size': 28, 'prot_window_size': 3, 'model_for_fs': 'Ridge', 'rate_for_fs': 0.15031751056542952, 'max_depth': 7, 'learning_rate': 0.45534937647958285, 'n_estimators': 254, 'min_child_weight': 9, 'gamma': 0.8026363932739038}. Best is trial 4 with value: 92.31042418115045.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.94it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:23<00:00,  7.16s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:36<00:00,  1.83s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.95it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:36<00:00,  4.84s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:18<00:00,  1.07it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.87it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:26<00:00,  7.33s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:36<00:00,  1.81s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.95it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:33<00:00,  4.69s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:19<00:00,  1.02it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.94it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:23<00:00,  7.17s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:35<00:00,  1.78s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.92it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:37<00:00,  4.87s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:19<00:00,  1.02it/s]
# [I 2023-04-08 06:43:52,194] Trial 7 finished with value: 111.70527067630753 and parameters: {'pep_vector_size': 35, 'pep_window_size': 6, 'prot_vector_size': 40, 'prot_window_size': 7, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.4844117212810542, 'max_depth': 7, 'learning_rate': 0.9554484164471532, 'n_estimators': 547, 'min_child_weight': 1, 'gamma': 0.1321276332748439}. Best is trial 4 with value: 92.31042418115045.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.00it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:10<00:00,  6.51s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:32<00:00,  1.64s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.07it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:28<00:00,  4.40s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:17<00:00,  1.17it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.07it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:14<00:00,  6.70s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:32<00:00,  1.60s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.06it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:24<00:00,  4.24s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:17<00:00,  1.16it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.02it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:09<00:00,  6.47s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:31<00:00,  1.59s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.01it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:28<00:00,  4.41s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:17<00:00,  1.12it/s]
# [I 2023-04-08 07:01:38,667] Trial 8 finished with value: 97.31912892272639 and parameters: {'pep_vector_size': 32, 'pep_window_size': 19, 'prot_vector_size': 19, 'prot_window_size': 7, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.21459566144687262, 'max_depth': 8, 'learning_rate': 0.33686814341884963, 'n_estimators': 697, 'min_child_weight': 5, 'gamma': 0.06514508759624503}. Best is trial 4 with value: 92.31042418115045.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.22it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:54<00:00,  2.70s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:15<00:00,  1.26it/s]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.23955e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.30it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:39<00:00,  1.95s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.19it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.14it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:55<00:00,  2.78s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:15<00:00,  1.30it/s]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.88564e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Feature Extraction: 100%|██████████████████████| 20/20 [00:05<00:00,  3.34it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:37<00:00,  1.87s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.15it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.27it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:54<00:00,  2.71s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:15<00:00,  1.27it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.32it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:38<00:00,  1.94s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.18it/s]
# [I 2023-04-08 07:11:06,264] Trial 9 finished with value: 102.87331008630997 and parameters: {'pep_vector_size': 14, 'pep_window_size': 20, 'prot_vector_size': 7, 'prot_window_size': 9, 'model_for_fs': 'Ridge', 'rate_for_fs': 0.024485043765222134, 'max_depth': 4, 'learning_rate': 0.5251167626501524, 'n_estimators': 157, 'min_child_weight': 6, 'gamma': 0.6600930924352314}. Best is trial 4 with value: 92.31042418115045.

# %%
study_3.best_params
# Out:
# {'pep_vector_size': 49,
#  'pep_window_size': 13,
#  'prot_vector_size': 8,
#  'prot_window_size': 10,
#  'model_for_fs': 'ExtraTreeRegressor',
#  'rate_for_fs': 0.2918732060340875,
#  'max_depth': 7,
#  'learning_rate': 0.02591584266122024,
#  'n_estimators': 634,
#  'min_child_weight': 2,
#  'gamma': 0.5164584865786107}

# %%
pipe_3 = make_pipeline(current_target=current_target, **study_3.best_params)
pipe_3.fit((train_peptides, train_proteins, train_order), train_clinical)
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:18<00:00,  1.06it/s]
# Feature Extraction:  65%|██████▌   | 13/20 [03:49<01:59, 17.10s/it]
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
preds_updrs_3_test = pipe_3.predict((test_peptides, test_proteins, test_order))
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# Feature Extraction: 100%|██████████| 20/20 [02:14<00:00,  6.71s/it]
# Feature Extraction: 100%|██████████| 20/20 [00:19<00:00,  1.00it/s]

# %%
preds_test_df = test_order.copy()
preds_test_df['pred'] = preds_updrs_3_test

# %%
true_pred = preds_test_df.merge(test_clinical, on = ['patient_id', 'visit_month'])
true_pred = true_pred.dropna(subset='updrs_3')

# %%
print(smape_func(true_pred.updrs_3.values, 
                 true_pred['pred'].values))
# Out:
# 119.47978284515281

# %% [markdown]
# ## updrs_4

# %%
current_target = 'updrs_4'
study_4 = optuna.create_study()
study_4.optimize(objective, n_trials=10)
# Out:
# [I 2023-04-08 07:11:06,274] A new study created in memory with name: no-name-b35a5e52-c023-46ad-a53f-c16ba7456c74
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.13it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:59<00:00,  2.96s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:18<00:00,  1.09it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.16it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:41<00:00,  2.08s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.91it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.20it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:59<00:00,  2.99s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:18<00:00,  1.10it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.13it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:40<00:00,  2.01s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.88it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.11it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:59<00:00,  2.95s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:18<00:00,  1.11it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.12it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:41<00:00,  2.07s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.85it/s]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
# [I 2023-04-08 07:21:13,496] Trial 0 finished with value: 154.38223689918618 and parameters: {'pep_vector_size': 15, 'pep_window_size': 15, 'prot_vector_size': 45, 'prot_window_size': 5, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.14939865620600673, 'max_depth': 1, 'learning_rate': 0.5531303746999062, 'n_estimators': 124, 'min_child_weight': 6, 'gamma': 0.7366981712692301}. Best is trial 0 with value: 154.38223689918618.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.27it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:54<00:00,  2.72s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:17<00:00,  1.13it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.19it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:38<00:00,  1.93s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.95it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.24it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:55<00:00,  2.79s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:17<00:00,  1.12it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:05<00:00,  3.36it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:37<00:00,  1.88s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.92it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.24it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:54<00:00,  2.72s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:17<00:00,  1.14it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:06<00:00,  3.25it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:38<00:00,  1.93s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:10<00:00,  1.92it/s]
# [I 2023-04-08 07:30:55,587] Trial 1 finished with value: 163.98962480381724 and parameters: {'pep_vector_size': 14, 'pep_window_size': 17, 'prot_vector_size': 47, 'prot_window_size': 6, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.9650950738515609, 'max_depth': 3, 'learning_rate': 0.6655369852280302, 'n_estimators': 114, 'min_child_weight': 9, 'gamma': 0.0549717174282099}. Best is trial 0 with value: 154.38223689918618.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.65it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:59<00:00,  8.96s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:42<00:00,  2.12s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.64it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:03<00:00,  6.20s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.09s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.66it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:03<00:00,  9.17s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:42<00:00,  2.11s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.61it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:57<00:00,  5.85s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:22<00:00,  1.11s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.54it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:58<00:00,  8.90s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:41<00:00,  2.08s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.58it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:03<00:00,  6.18s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:22<00:00,  1.13s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
# [I 2023-04-08 07:53:56,500] Trial 2 finished with value: 156.0375344692901 and parameters: {'pep_vector_size': 43, 'pep_window_size': 9, 'prot_vector_size': 5, 'prot_window_size': 8, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.2519627550768874, 'max_depth': 1, 'learning_rate': 0.10562642026676682, 'n_estimators': 796, 'min_child_weight': 3, 'gamma': 0.5167014830351004}. Best is trial 0 with value: 154.38223689918618.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.10it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:00<00:00,  6.05s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:31<00:00,  1.56s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.04it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:22<00:00,  4.14s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:16<00:00,  1.19it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.05it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:03<00:00,  6.17s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:31<00:00,  1.57s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.06it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:19<00:00,  3.96s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:16<00:00,  1.19it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.08it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:01<00:00,  6.07s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:31<00:00,  1.56s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.07it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:22<00:00,  4.12s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:17<00:00,  1.14it/s]
# [I 2023-04-08 08:11:01,085] Trial 3 finished with value: 156.6150913734269 and parameters: {'pep_vector_size': 30, 'pep_window_size': 6, 'prot_vector_size': 36, 'prot_window_size': 5, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.8955231943074614, 'max_depth': 8, 'learning_rate': 0.1850852096679211, 'n_estimators': 788, 'min_child_weight': 7, 'gamma': 0.17578742871350161}. Best is trial 0 with value: 154.38223689918618.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.64it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:05<00:00,  9.28s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:44<00:00,  2.22s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.63it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:07<00:00,  6.39s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:22<00:00,  1.14s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.62it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:10<00:00,  9.52s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:43<00:00,  2.18s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.63it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:59<00:00,  6.00s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:23<00:00,  1.16s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.57it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:03<00:00,  9.15s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:43<00:00,  2.17s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.66it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:06<00:00,  6.30s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:23<00:00,  1.18s/it]
# [I 2023-04-08 08:34:38,855] Trial 4 finished with value: 159.95564421058114 and parameters: {'pep_vector_size': 44, 'pep_window_size': 20, 'prot_vector_size': 31, 'prot_window_size': 9, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.49765480441926335, 'max_depth': 2, 'learning_rate': 0.41294260585710574, 'n_estimators': 168, 'min_child_weight': 3, 'gamma': 0.7853882749955646}. Best is trial 0 with value: 154.38223689918618.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.75it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:45<00:00,  8.30s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:40<00:00,  2.00s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.72it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:53<00:00,  5.67s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:20<00:00,  1.03s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.75it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:50<00:00,  8.53s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:39<00:00,  1.97s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.76it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:48<00:00,  5.42s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.06s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.77it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:44<00:00,  8.22s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:39<00:00,  1.97s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.74it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:53<00:00,  5.69s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.07s/it]
# [I 2023-04-08 08:56:12,933] Trial 5 finished with value: 164.04932926951747 and parameters: {'pep_vector_size': 40, 'pep_window_size': 17, 'prot_vector_size': 18, 'prot_window_size': 4, 'model_for_fs': 'Ridge', 'rate_for_fs': 0.5862118243299449, 'max_depth': 1, 'learning_rate': 0.5936283845392019, 'n_estimators': 806, 'min_child_weight': 10, 'gamma': 0.04167695997409659}. Best is trial 0 with value: 154.38223689918618.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.67it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:18<00:00,  3.91s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.06s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.70it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:54<00:00,  2.71s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.68it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.71it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:19<00:00,  3.99s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.05s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=9.00796e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.71it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:52<00:00,  2.63s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.65it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.70it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:17<00:00,  3.88s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:20<00:00,  1.03s/it]
# C:\Users\Max\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=1.10095e-16): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.70it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:54<00:00,  2.72s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.67it/s]
# [I 2023-04-08 09:08:14,147] Trial 6 finished with value: 165.6454322418219 and parameters: {'pep_vector_size': 20, 'pep_window_size': 19, 'prot_vector_size': 7, 'prot_window_size': 4, 'model_for_fs': 'Ridge', 'rate_for_fs': 0.9868347887317537, 'max_depth': 3, 'learning_rate': 0.7401510516582399, 'n_estimators': 157, 'min_child_weight': 2, 'gamma': 0.3505128458841794}. Best is trial 0 with value: 154.38223689918618.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.65it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:59<00:00,  9.00s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:42<00:00,  2.14s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.64it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:03<00:00,  6.15s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.10s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.66it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [03:04<00:00,  9.21s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:42<00:00,  2.12s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.66it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:57<00:00,  5.87s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:22<00:00,  1.13s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.62it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:59<00:00,  8.95s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:42<00:00,  2.13s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.62it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [02:04<00:00,  6.21s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:22<00:00,  1.14s/it]
# [I 2023-04-08 09:31:20,874] Trial 7 finished with value: 158.5517529344165 and parameters: {'pep_vector_size': 43, 'pep_window_size': 8, 'prot_vector_size': 16, 'prot_window_size': 10, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.7646917714718511, 'max_depth': 2, 'learning_rate': 0.28873668089780236, 'n_estimators': 517, 'min_child_weight': 3, 'gamma': 0.509656620269127}. Best is trial 0 with value: 154.38223689918618.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.76it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:17<00:00,  3.90s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.07s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.72it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:54<00:00,  2.70s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:11<00:00,  1.70it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.70it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:19<00:00,  3.99s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.06s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.69it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:52<00:00,  2.62s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.66it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.70it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:17<00:00,  3.89s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:21<00:00,  1.05s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:07<00:00,  2.69it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:53<00:00,  2.70s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:12<00:00,  1.66it/s]
# [I 2023-04-08 09:43:22,685] Trial 8 finished with value: 160.12161363558616 and parameters: {'pep_vector_size': 20, 'pep_window_size': 6, 'prot_vector_size': 10, 'prot_window_size': 4, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.058232203183018715, 'max_depth': 10, 'learning_rate': 0.13229269035623864, 'n_estimators': 940, 'min_child_weight': 2, 'gamma': 0.4556307133342436}. Best is trial 0 with value: 154.38223689918618.
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.14it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:54<00:00,  5.75s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:29<00:00,  1.48s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.15it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:19<00:00,  3.99s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:15<00:00,  1.28it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.17it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:59<00:00,  6.00s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:29<00:00,  1.46s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.15it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:16<00:00,  3.83s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:16<00:00,  1.25it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.16it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:55<00:00,  5.77s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:28<00:00,  1.43s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:09<00:00,  2.12it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [01:20<00:00,  4.00s/it]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:16<00:00,  1.24it/s]
# [I 2023-04-08 09:59:32,561] Trial 9 finished with value: 166.06426103790452 and parameters: {'pep_vector_size': 29, 'pep_window_size': 15, 'prot_vector_size': 13, 'prot_window_size': 4, 'model_for_fs': 'ExtraTreeRegressor', 'rate_for_fs': 0.6117971959431044, 'max_depth': 4, 'learning_rate': 0.9051717070946517, 'n_estimators': 129, 'min_child_weight': 8, 'gamma': 0.7144993961995945}. Best is trial 0 with value: 154.38223689918618.

# %%
study_4.best_params
# Out:
# {'pep_vector_size': 15,
#  'pep_window_size': 15,
#  'prot_vector_size': 45,
#  'prot_window_size': 5,
#  'model_for_fs': 'ExtraTreeRegressor',
#  'rate_for_fs': 0.14939865620600673,
#  'max_depth': 1,
#  'learning_rate': 0.5531303746999062,
#  'n_estimators': 124,
#  'min_child_weight': 6,
#  'gamma': 0.7366981712692301}

# %%
pipe_4 = make_pipeline(current_target=current_target, **study_4.best_params)
pipe_4.fit((train_peptides, train_proteins, train_order), train_clinical)
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:06<00:00,  3.32it/s]
# Feature Extraction: 100%|██████████| 20/20 [01:41<00:00,  5.05s/it]
# Feature Extraction: 100%|██████████| 20/20 [00:32<00:00,  1.62s/it]

# %%
preds_updrs_4_test = pipe_4.predict((test_peptides, test_proteins, test_order))
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:06<00:00,  3.07it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:41<00:00,  2.09s/it]
# Feature Extraction: 100%|██████████| 20/20 [00:07<00:00,  2.55it/s]

# %%
preds_test_df = test_order.copy()
preds_test_df['pred'] = preds_updrs_4_test

# %%
true_pred = preds_test_df.merge(test_clinical, on = ['patient_id', 'visit_month'])
true_pred = true_pred.dropna(subset='updrs_4')

# %%
print(smape_func(true_pred.updrs_4.values, 
                 true_pred['pred'].values))
# Out:
# 162.736571157652
